# %%
# Rule bases sentiment analysis
# - rule based (e.g. "great" = positive, "sad" = negative)
# - words are given a polarity score, usually between -1 and 1
# - the scores for words in a sentence are averaged to get the overall sentiment score

# %%
sentence_1 = "i had a great time at the movie it was really funny"
sentence_2 = "i had a great time at the movie but the parking was terrible"
sentence_3 = "i had a great time at the movie but the parking wasn't great"
sentence_4 = "i went to see a movie"

# %%
from textblob import TextBlob

# %%
print(sentence_1)
sentiment_1 = TextBlob(sentence_1)
print(sentiment_1.sentiment.polarity)
# Out:
# i had a great time at the movie it was really funny
# 0.525

# %%
print(sentence_2)
sentiment_2 = TextBlob(sentence_2)
print(sentiment_2.sentiment.polarity)
# Out:
# i had a great time at the movie but the parking was terrible
# -0.09999999999999998

# %%
print(sentence_3)
sentiment_3 = TextBlob(sentence_3)
print(sentiment_3.sentiment.polarity)
# Out:
# i had a great time at the movie but the parking wasn't great
# 0.8

# %%
print(sentence_4)
sentiment_4 = TextBlob(sentence_4)
print(sentiment_4.sentiment.polarity)
# Out:
# i went to see a movie
# 0.0

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
v_sentence_1 = analyzer.polarity_scores(sentence_1)
print(v_sentence_1)
v_sentence_2 = analyzer.polarity_scores(sentence_2)
print(v_sentence_2)
v_sentence_3 = analyzer.polarity_scores(sentence_3)
print(v_sentence_3)
v_sentence_4 = analyzer.polarity_scores(sentence_4)
print(v_sentence_4)
# Out:
# {'neg': 0.0, 'neu': 0.578, 'pos': 0.422, 'compound': 0.807}
# {'neg': 0.234, 'neu': 0.621, 'pos': 0.144, 'compound': -0.3818}
# {'neg': 0.247, 'neu': 0.611, 'pos': 0.142, 'compound': -0.4387}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# Pre-trained Transformer models

# %%
import transformers
from transformers import pipeline
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
sentiment_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sentiment_pipeline = pipeline("sentiment-analysis")
#
# File ~/Development /Udemy/AI Engineer Course (2025)/NLP/.venv/lib/python3.11/site-packages/transformers/pipelines/__init__.py:940, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     938 if isinstance(model, str) or framework is None:
#     939     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 940     framework, model = infer_framework_load_model(
#     941         model,
#     942         model_classes=model_classes,
#     943         config=config,
#     944         framework=framework,
#     945         task=task,
#     946         **hub_kwargs,
#     947         **model_kwargs,
#     948     )
#     950 model_config = model.config
#     951 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File ~/Development /Udemy/AI Engineer Course (2025)/NLP/.venv/lib/python3.11/site-packages/transformers/pipelines/base.py:240, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     214 """
#     215 Select framework (TensorFlow or PyTorch) to use from the `model` passed. Returns a tuple (framework, model).
#     216
#    (...)    237     `Tuple`: A tuple framework, model.
#     238 """
#     239 if not is_tf_available() and not is_torch_available():
# --> 240     raise RuntimeError(
#     241         "At least one of TensorFlow 2.0 or PyTorch should be installed. "
#     242         "To install TensorFlow 2.0, read the instructions at https://www.tensorflow.org/install/ "
#     243         "To install PyTorch, read the instructions at https://pytorch.org/."
#     244     )
#     245 if isinstance(model, str):
#     246     model_kwargs["_from_pipeline"] = task
#
# RuntimeError: At least one of TensorFlow 2.0 or PyTorch should be installed. To install TensorFlow 2.0, read the instructions at https://www.tensorflow.org/install/ To install PyTorch, read the instructions at https://pytorch.org/.
